# %%
import pandas as pd

# %%
df = pd.read_csv('sort_data_0_1.csv')
df = df.drop([df.columns[0],df.columns[1]],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 745 entries, 0 to 744
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   도시        745 non-null    object
#  1   테마        0 non-null      float64
#  2   도로명주소     668 non-null    object
#  3   지번주소      600 non-null    object
#  4   위도        745 non-null    float64
#  5   경도        745 non-null    float64
#  6   구글별점      0 non-null      float64
#  7   검색건수      745 non-null    int64
#  8   데이터셋카테고리  0 non-null      float64
#  9   지도상 관광지명  745 non-null    object
#  10  별점        745 non-null    object
#  11  리뷰개수      745 non-null    object
#  12  관광지소개     745 non-null    object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 75.8+ KB

# %%
# None값이 들어임으로 인해, dtype이 object에서 int or float 으로 변환
df.loc[df['별점'] == 'None','별점'] = 0
df['구글별점'] = df['구글별점'].astype('float')
df.loc[df['리뷰개수'] == 'None','리뷰개수'] = 0
df['리뷰개수'] = df['리뷰개수'].astype('int')

# %%
# 수집안된 행
zero_search_stat = df.loc[df['검색건수'] == 0]
zero_star_stat = df.loc[df['별점'] == 0]
zero_review_stat = df.loc[df['리뷰개수'] == 0]

# %%
# 검색건수를 제대로 추출하지 못한 관광지에 대해 수작업으로 기입
#print(zero_search_stat['지도상 관광지명'])
edit_zero_search_stat=[24600,372000,824000,143000,31200,340000,131000,50900,645000,326000,70900,
132000,50600,160000,9930,52100,39300,2330,63200,203000,21300,108000,384000,
30700,221000,86300,60900,1590000,404000,187000,3560000,705000,111000,18100,
576000,128000,372000,231000,454000,97900,271000,772000,249000,26600,3380000,
40000,68300,16400,1210000,6080000,3560000,72900,116000,105000,243000,168000,
318000]
zero_search_stat['검색건수'] = edit_zero_search_stat
edit_search_index = zero_search_stat.index
df.loc[edit_search_index] = zero_search_stat
# Out:
# C:\Users\dalyn\AppData\Local\Temp\ipykernel_42892\354576215.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zero_search_stat['검색건수'] = edit_zero_search_stat

# %%
# 구글맵 자체에 별점이 달릴수 없는 지도명(상호 또는, 관광지가 아님)
print(zero_star_stat['지도상 관광지명'])
edit_zero_star_stat = []
# Out:
# 79         비비정마을
# 105    천안종합휴양관광지
# 164       한중우호센터
# 239        다산초당길
# 302    유애서원(경장각)
# 328    조선대학교 장미원
# 346        녹색에너지
# 438       금정산성마을
# 466          해오름
# 478      2시간 18분
# 479        비프광장로
# 483          광복로
# 492       강감찬전시관
# 543      (주)용평관광
# 615        문동휴양지
# 717          모원재
# 723         금성관길
# Name: 지도상 관광지명, dtype: object

# %%
#별점과 같음
print(zero_review_stat['지도상 관광지명'])
edit_zero_review_stat=[]
# Out:
# 79         비비정마을
# 105    천안종합휴양관광지
# 164       한중우호센터
# 239        다산초당길
# 302    유애서원(경장각)
# 328    조선대학교 장미원
# 346        녹색에너지
# 438       금정산성마을
# 466          해오름
# 478      2시간 18분
# 479        비프광장로
# 483          광복로
# 492       강감찬전시관
# 543      (주)용평관광
# 615        문동휴양지
# 717          모원재
# 723         금성관길
# Name: 지도상 관광지명, dtype: object

# %%
# 별점이 없는 데이터는 모델의 파라미터로써의 역할을 제대로 수행하지 못할것이기에 관광지 제외가 맞다고 판단됨,
# 더군다나 위의 데이터들은 관광지로써 판단할수 있는 지역이 아님
drop_index = zero_review_stat.index
df = df.drop(drop_index,axis=0)

# %%
for i,text in zip(df.index,df['관광지소개']):
    print(f'{i} : {text}')
# Out:
# 0 : 운동.숙박.휴양시설을 갖춘 체류형복합문화단지
# 1 : 하회마을등 주변의전통문화자원과 연계된 관광여가단지
# 2 : 병지방계곡,캠핑장
# 3 : 명사20리 라고 불리는 8km에 이르는 넓고 긴 양질의 백사장과 빼어난 해송림 등 우수한 자연자원을 보유한 관광지
# 4 : 해수욕장의 청정 자연자원과 장사상륙작전이라는 역사적 사건을 보존한 관광지
# 5 : 풍수원성당, 유물전시관, 산책로
# 6 : 스키장, 골프장, 곤돌라, 콘도
# 7 : 개발진행중
# 8 : 천상열차분야지도를 제작한 충남 서산 출신 고려말 천문학자 류방택 선생의 뜻을 기려 설립된 과학관
# 9 : 철새도래시기에는 천수만에 도래하는 철새들을 탐조투어를 통해 볼 수 있고, 특별프로그램 기간에는 각종 체험행사 등을 경험할 수 있으며, 4D 영상 등의 볼거리가 있음.
# 10 : 용현계곡 한가운데 자리해 심산유곡의 경치를 자랑하는 산림휴양의 적지
# 11 : 500년 옛모습을 잘 간직한 조선시대 석축 읍성
# 12 : 만해 한용운의 일제강점기 머물던 집
# 13 : 최고급 요정에서 도심속 도량으로 환골탈퇴
# 14 : 한국의 전통가구를 한눈에 볼수있는 곳
# 15 : 명량해전의 울둘목 해역이 한눈에 보이는 역사가 숨쉬는 관광지
# 16 : 신비의바닷길이 열리는 축제명소
# 17 : 예술인의 멋과 정취를 느낄수 있는 아리랑마을
# 18 : 백두산과 한라산의 중간지점에 위치하여 우리나라에서 기가 가장 센 곳이며 정상에 있는 참성단에서 매해 제례를 올리고 칠선녀가 전국 체육대회의 성화를 채화함
# 19 : 추사 김정희가 말년에 4년간 과지초당에서 지내며 꽃피웠던 학문과 예술의 정수를 알리기 위해 추사박물관 개관함.
# 20 : 대하, 우럭, 새조개, 꽃게 등 사시사철 싱싱한 수산물을 맛볼수 있으며, 잔잔한 은빛 수면으로 석양이 아름다움을 느낄 수 있음
# 21 : 백마강과 함께 가족단위 공원 심터 및 생활체육을 즐길수 있는 웰빙관광지
# 22 : 역사문화환경을 구축하여 부여 대표 관광명소
# ...

# %%
#관광지 소개가 적절하지 못한 데이터가 들어가있기에 , 수정이 필요 한 인덱스들
edit_index = [7,28,148,401,417,418,419,420,421,422,423,424,425]
link_index = [520,521,522,523,524,525,526,527,528,529,530]

# %%
df.loc[link_index]['지도상 관광지명']
# Out:
# 520          내원사계곡
# 521       대운산자연휴양림
# 522          법기저수지
# 523        양산시립박물관
# 524           양산타워
# 525        에덴밸리리조트
# 526            임경대
# 527    통도사대전포교원용수사
# 528         통도환타지아
# 529     홍룡폭포(虹龍瀑布)
# 530       황산문화체육공원
# Name: 지도상 관광지명, dtype: object

# %%
# for tourism,intro in zip(df.iloc[edit_index]['지도상 관광지명'],df.iloc[edit_index]['관광지소개']):
#     print(f'{tourism} : {intro}')
for tourism,intro in zip(df.loc[link_index]['지도상 관광지명'],df.loc[link_index]['관광지소개']):
    print(f'{tourism} : {intro}')
edit_intro = ['서산이 자랑하는 서산 9경 중 제3경은 천수만 간월암이다. 이곳은 아름다운 해넘이를 볼 수 있는 명소로 알려져 있다. 그런 이유로 간월도는 매년 많은 사진사들이 몰려들고 있다. 그런데 이곳에는 사진사만 모이는 것이 아니라 미식을 추구하는 많은 식객들도 이곳을 자주 방문한다고 한다. 바로 간월도에서 유명한 별미, 굴 요리를 맛보기 위해서다. 간월도에서 일몰만큼 유명한 굴 요리는 기력회복은 물론 두말할 것도 없는 뛰어난 맛을 가지고 있기 때문이다.',
             '대천, 변산해수욕장과 함께 서해안 3대 해수욕장으로 꼽히는 만리포해수욕장은 백사장의 길이가 약 3km, 폭 약 250m이상, 면적 20만㎡입니다.고운 모래로 백사장이 좋고, 경사가 완만하고 수심이 얕아 가족 단위의 해수욕장으로 사랑받고 있습니다.조석간만의 차와 조류 변화가 심한 편이어서 썰물 때의 수영은 삼가는 것이 좋습니다.충분한 숙박시설과 위락시설을 갖추고 있으며 인근 방파제에서는 낚시도 즐길 수 있습니다.',
             '대전의 밤은 낮보다 화려하다. 중구 은행동 으능정이 문화의 거리에 가면 확실히 느낄 수 있다. 쇼핑과 문화 예술 충전소인 으능정이 문화의 거리는 밤늦은 시간까지 북적거리는 사람들과 빛나는 네온사인으로 가득하다. 여기에 대전의 새로운 야간 명소로 떠오른 스카이로드까지 더해져 어디서도 볼 수 없는 도시의 야경을 선사한다.',
             '대전 동춘당 종택은 조선 후기 호서지역 명현인 동춘당 송준길의 종가로 별천위와 기타 제례가 그대로 전승되고 있고, 문중에서 소장하고 있는 방대한 고문서 등은 조선 중기부터 근대에 이르기까지 집안의 생활사와 지역 향촌사회의 변화를 볼 수 있는 귀한 자료이기에 중요민속문화재로 지정하여 보존할 가치가 있다.',
             '대전오월드는 ‘주랜드+플라워랜드+조이랜드+버드랜드’의 복합적인 공간으로 구성된 온가족이 함께 즐길 수 있는 중부권 이남 최대 규모의 테마공원입니다.오월드에서 경험할 수 있는 아프리카 사파리와 한국늑대 사파리, 마운틴 사파리 등 눈앞에서 생생하게 살아 숨 쉬는 동물들의 이야기를 들어보세요!또한, 꽃과 물과 빛이 어우러진 향기로운 꽃의 세계와 짜릿한 즐거움을 주는 놀이시설, 희귀새와 열대정원이 어우러진 환상의 버드체험까지 오월드에서 한번에 즐겨보세요!',
             '뿌리공원은 민과 관이 유기적인 협조체계로 조성된 전국 유일의 "효" 테마공원으로서 자신의 뿌리를 되찾을 수 있는 성씨별 조형물과 사신도 및 12지지를 형상화한 뿌리 깊은 샘물, 각종 행사를 할 수 있는 수변무대, 잔디 광장과 공원을 한눈에 바라볼 수 있는 전망대, 팔각 정자뿐만 아니라 산림욕장, 자연관찰원, 야간경관조명, 은하수 터널 등 다양한 시설이 갖추어진 체험학습의 산 교육장입니다.',
             '우리나라 최초의 국제박람회기구(BIE)공인 전문 엑스포로 개최되었던 "93년 대전세계박람회"를 기념하기 위해 그 시설과 부지를 국민 과학교육의 장으로 활용하기 위하여 조성된 과학공원이다. 엑스포과학공원에는 대전세계박람회(1993)의 상징탑인 한빛탑과 대전세계박람회를 기념하기 위해 새롭게 재단장한 대전엑스포기념관이 있고, 각국에서 개최하였던 엑스포의 기념품 및 상징물이 전시되어있는 세계엑스포기념박물관에서는 200년간의 엑스포의 역사를 감상할 수 있으며, 어린이들이 교통관련 교육 및 교통의 역사를 체험할 수 있는 대전교통문화센터가 운영되고 있다. 이 외의 시뮬레이션관, 돔영상관, 전기에너지관, 첨단과학관, 에너지관, 자기부상열차, 음악분수, 꿈돌이광장 등은 대전시의 엑스포재창조사업 추진으로 현재 시설 철거 작업중이므로 관람이 불가능하다.',
             '한밭수목원은 정부대전청사와 과학공원의 녹지축이 연결된 도심형 수목원으로 둔산대공원 내에 위치하고 있다. 수목원의 규모는 39만㎡이며, 목본류 1,083종, 초본류 1,087종 등 총 2,170종의 식물종이 전시되고 있다. 이중 1,504종에 달하는 수목유전자원을 보유하고 있다.한밭수목원은 다양한 식물유전자원 확보하고, 도심 속의 인공수목원을 자연과 조화를 이루도록 조성하며, 청소년을 위한 자연체험의 장 및 시민을 위한 휴식공간 제공을 목적으로 조성되었다.',
             '계족산을 즐겨 찾던 조웅래 회장은 2006년 어느 날, 가까운 지인들과 함께 산을 오르던 중 하이힐을 신고 온 여성에게 자신의 신발을 벗어주고 맨발로 돌길을 걷게 됩니다. 그날 밤 꿀잠을 자게 된 조웅래 회장은 맨발의 첫 경험을 결코 잊을 수 없었습니다. 이후 조 회장은 ‘이 좋은 것을 혼자 누리기엔 아깝다. 보다 많은 사람들과 함께 해보자’ 라는 생각에 14.5km 돌길에 전국의 질 좋은 황토를 깔기 시작했습니다. 지금은 많은 사람들이 지친 일상을 치유하고 막혔던 대화의 창을 여는 명품 맨발 황톳길이 되었습니다. 계족산황톳길은 문화체육관광부와 한국관광공사가 주관하는 걷기여행 실태조사에서 ‘전국에서 가장 기억에 남는 걷기 여행길’ 2018년 11위, 2019년 8위에 각각 올랐습니다.',
             '시각적으로 아름답고 이용객들이 함께 활동할수 있는 공원을 만들기 위해 설립된 대청호반 자연생태공원입니다. 쉽게 갈수있고 문화적체험공간도 조성되어 있어 방문객들이 편하게 즐기다 가실수 있습니다.',
             '운장산에서 남쪽으로 뻗어내린 능선이 연석산을 이루고, 이어서 삿갓봉[입봉]을 형성한 뒤에 부귀면에 이르러 부귀산을 맺고, 동쪽으로 흘러 시루봉을 거쳐 성주봉으로 이어진다. 부귀산에서 이어지는 시루봉은 동북쪽으로 갈수록 높이가 점점 낮아진다. 시루봉 서-북 방향으로 용담호로 합류되는 정자천이 흐르며, 국가 지원 지방도 49호선이 정자천과 평행하여 놓여 있으며 정자천이 만든 범람원에 마을이 형성되어 있다. 시루봉 동쪽으로는 좁고 긴 평지가 있어 마을이 형성되어 있고, 지방도 795호선이 남북 방향으로 지난다.',
             '장태산자연휴양림은 대전광역시 서구 장안동과 충청남도 금산군 복수면 신대리 경계의 안평산(470.2m)옆에 있는 산으로 대둔산에 뿌리를 둔 산줄기가 장엄하고 아름답게 뻗친 곳이다. 그림같은 호수와 기암 괴석이 어우러져 일대 장관을 이룬다.',
             '지하 350m 화강암 단층 각력대를 따라 흐르는 온천수는 중금속이 전혀 검출되지 않는 래디움성분의 단순천입니다.몸에 이로운 60여가지의 성분이 포함되어 있어 각종 성인병 예방에 도움을 줍니다.']
link_intro = ['내원사계곡은 예부터 소금강이라 불릴 정도로 자연경관이 빼어나고 사시사철 맑고 깨끗한 물이 흘러 신비한 계곡으로 불리었다. 계곡 곳곳에는 삼층바위가 첩첩이 서 있으며 절벽에 “소금강”이란 글자가 뚜렷이 새겨져 있으며 병풍 모양으로 바위가 길게 뻗어져 있어 병풍바위라 불리는 것도 있다.',
              '대운산은 맑은계곡과 유명 등산로가 있으며 휴양림의 노천을 따라아름다운 산책로도 있습니다. 숲속엔 쉼터가 있어 숲속에서의 새로운 볼거리를 제공합니다. 대운산자연휴양림은 아름다운 경치와 더불어 펜션의 깨끗한인테리어와 푸근한 서비스로 쾌적한 시간을 즐기실 수 있습니다.',
          '법기수원지(法基水源池)는 경상남도 양산시 동면 법기로에 위치한 대한민국의 저수지이다. 1932년에 축조되었으며 상수원 보호를 위해 일반인의 접근이 차단되었다. 그러나 79년 후 2011년 7월 15일 일반인에게 개방되었다. 저수능력은 150만t이다.',
             '양산시립박물관은 양산의 역사와 문화를 한 눈에 볼 수 있는 제1종 종합박물관의 면모를 가지고 있다. 시립박물관의 핵심 시설인 전시실은 역사실, 고분실, 어린이 역사체험실, 기획전시실, 대강당, 시청각실 등으로 구성되어 있다',
             '양산타워는 경상남도 양산시 동면 석산리 신도시 지구 5만3904m2 부지에 620여억원을 들여 조성한 자원회수시설의 굴뚝을 이용해 전망대와 레스토랑을 설치한 건축물이다.',
             '에덴밸리 리조트는 스키장과 골프장이 바로 인접해 있어 편리하게 이용하실 수 있으며 경남 최대 규모의 테마파크인 통도환타지아가 45분 거리에 있습니다. 또한, 차로 50분이면 홍매화로 유명한 통도사까지 가실 수 있습니다.',
             '임경대는 경남 양산 원동면에 위치하고 있는 통일신라시대의 정자이다. 신라의 고운 최치원이 즐겨 놀던 정자로 고운대 혹은 최공대라고 불린다. 신라 시대 당시 황산강(현 낙동강)의 절경이 지금도 남아있는 듯 정자에 오르면 가슴이 탁 트이는 듯 시원한 느낌을 받을 수 있다.',
             '지금 운영하고 있는 용수사는 대전 시내에 있는 도심 사찰입니다. 그래서 부처님의 전도선언 이후에 전법도량으로서의 역할을 하고 있습니다. 또 통도사 대전 불교대학, 인가가 된 불교대학을 운영하고 있습니다. 기초반, 중등반, 심화반으로 해서 지금 백여 분 불자 스님들이 부처님 공부를 위해 전념하고 있는 그런 도량입니다.',
             '통도환타지아는 영남 알프스인 영취산 아래 위치한 부산, 경남권 내 최대의 테마공원이다. 30여 기종의 유희시설과 대규모 수영장, 자연호수, 이벤트광장 및 대형 야외공연장 등을 갖추고 있을 뿐 아니라 다양한 이벤트 행사로 놀거리, 볼거리 등을 제공하고 있다.',
             '홍룡폭포는 20m로 상, 중, 하 3단으로 떨어지는 구조로 주변 경관과 어울려 양산 8경 중 4경에 속해 있을 만큼 빼어난 풍광을 자랑하고 있습니다. 깎아지른 직선 기암절벽 아래로 떨어지는 폭포수는 날씨가 맑은 날 찾으면 무지개가 뜨는 걸 볼 수 있다고 합니다.',
             '황산문화체육공원 국민여가캠핑장은 낙동강의 수려한 자연경관을 배경으로 경남, 부산, 울산지역의 가족단위 캠핑장으로 일명 명품공원 캠핑장으로 알려져 있다. 캠핑장 사이트는 오토캠핑장 36면, 일반캠핑장 75면이 있으며, 화장실, 샤워장, 개수대가 갖춰져 있다. 모든 편의시설들이 깨끗하게 잘 관리되고 있다. 황산문화체육공원은 캠핑장 외에도 파크골프장, 자전거도로, 강변산책로와 운동시설 등을 갖춘 종합공원으로 워낙 넓어 둘러보는 시간이 3시간 가량 걸린다. 무엇보다 넓은 공간에 조성된 캠핑장이다 보니 아이들이 마음껏 뛰고 달릴 수 있어 좋다. ']
df.loc[edit_index,'관광지소개'] = edit_intro
df.loc[link_index,'관광지소개'] = link_intro
# Out:
# 내원사계곡 : http://naewonsa.net/sub01/sub01.php
# 대운산자연휴양림 : https://www.foresttrip.go.kr/pot/rm/ri/selectRcrfrIntrdDtlView.do?hmpgId=ID02030038&menuId=002001
# 법기저수지 : http://terms.naver.com/entry.naver?docId=3377216&cid=42856&categoryId=42856
# 양산시립박물관 : https://www.yangsan.go.kr/museum/contents.do?mId=0601000000, https://www.yangsan.go.kr/tour/spot/view.do?mId=0108000000&idx=203
# 양산타워 : http://tower.yangsan.go.kr/sub/menu01_01.php, https://www.yangsan.go.kr/tour/spot/view.do?mId=0109000000&idx=204
# 에덴밸리리조트 : https://www.yangsan.go.kr/tour/spot/view.do?mId=0106000000&idx=41, https://www.yangsan.go.kr/tour/spot/view.do?mId=0106000000&idx=42
# 임경대 : http://www.yangsan.go.kr/tour/spot/view.do?mId=0102000000&idx=13
# 통도사대전포교원용수사 : http://tongdosa.or.kr/bbs/content.php?co_id=menu01103
# 통도환타지아 : https://www.yangsan.go.kr/tour/spot/view.do?mId=0106000000&idx=32
# 홍룡폭포(虹龍瀑布) : https://www.yangsan.go.kr/tour/spot/view.do?mId=0102000000&idx=20
# ...

# %%
df.to_csv('data_cleansing_0_1.csv')
